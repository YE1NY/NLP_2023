# %% [markdown]
# <a href="https://colab.research.google.com/github/YE1NY/NLP_2023/blob/main/4_1_IfStatement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 🐾  Some useful tips for statements (e.g., if, for, while, etc.), functions or class
#
# 1️⃣ The code line including a statement or a definition should end with a colon (:).
#
# 2️⃣ Following executable codes should be indicated by indentation. When you hit the ENTER key for a second code line, indentation is automatically generated. However, when indentation disappears for some reason, you can do this with a tab or a spacebar.
#
# 3️⃣ All executable code lines should have regular intervals.

# %%
x=100
y=95

if x>y:
  print('x is greater than y.')


else:
  print('x is smaller than or equal to y.')

# %%
x=100
y=100
if x>y:
  print('x is graeter than y')

else:
  print('x is smalle than or equal to y ')
# Out:
# x is smalle than or equal to y

# %%
x=0
y=0

if x > y:
  print('x is greater than y')

else:
  print('x is smaller than or equal to y')

# %%
x=345
y=678

if x>y:
  print('x is greater than y.')


else:
  print('x is smaller than or equal to y.')

# %%
x=222
y=503

if x>y:
  print('x is greater than y')
  pirnt('x is smaller or equal than y')

# %%
listdata = ['a', 'b', 'c']
if 'a' in listdata:
  print ('a가 listdata 안에 있습니다.')
  print(listdata)

# %%
listdata = ['a', 'b', 'c']
if 'a' in listdata:
  print ('a가 listdata 안에 있습니다. a is in listdata')
  print(listdata)
# Out:
# a가 listdata 안에 있습니다. a is in listdata
# ['a', 'b', 'c']

# %% [markdown]
# ## 🔍 <font color='purple'> Relating issues of if statements are evailable in chapters 09 ~ 10 of 파이썬 200제 .

# %% [markdown]
# 여기서부터 내 연습문제

# %%
#if문 연습

x=90
y=70

if x>y:
  print('합격입니다.')
# Out:
# 합격입니다.
